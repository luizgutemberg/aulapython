# %% [markdown]
# Compare os outliers dos dois primeiros anos da atual gestão com os dois primeiros anos da gestão anterior no que diz
# respeito a estelionato na região metropolitana.
# O padrão se manteve?
# Alguma delegacia deixou de ser outlier? Alguma delegacia
# passou a ser considerada outlier que anteriormente não era ?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', encoding='ISO-8859-1', sep=';')
df.columns
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'letalidade_violenta', 'tentat_hom',
#        'lesao_corp_dolosa', 'estupro', 'hom_culposo', 'lesao_corp_culposa',
#        'roubo_transeunte', 'roubo_celular', 'roubo_em_coletivo', 'roubo_rua',
#        'roubo_veiculo', 'roubo_carga', 'roubo_comercio', 'roubo_residencia',
#        'roubo_banco', 'roubo_cx_eletronico', 'roubo_conducao_saque',
#        'roubo_apos_saque', 'roubo_bicicleta', 'outros_roubos', 'total_roubos',
#        'furto_veiculos', 'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
#        'recuperacao_veiculos', 'apf', 'aaapai', 'cmp', 'cmba', 'ameaca',
# ...

# %%
# Função para calcular os outliers de estelionato em um período específico
def encontrar_outliers_estelionato(df, ano, nome_periodo):
    print(f"\n--- ANÁLISE: {nome_periodo} ({ano}) ---")

# %%
# Definição dos Períodos de Gestão
anos_atual = [2023, 2024]
anos_anterior = [2019, 2020]

# %%
# 1. Filtrar pelos anos da gestão
df_periodo = df[df['ano'].isin(ano)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # 1. Filtrar pelos anos da gestão
# ----> 2 df_periodo = df[df['ano'].isin(ano)]
#
# NameError: name 'ano' is not defined
